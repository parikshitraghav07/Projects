# %% [markdown]
# <a href="https://colab.research.google.com/github/parikshitraghav07/Projects/blob/main/Icecream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Ice=pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Ice%20Cream.csv')

# %%
Ice
# Out:
#      Temperature  Revenue
# 0           24.6      535
# 1           26.1      626
# 2           27.8      661
# 3           20.6      488
# 4           11.6      317
# ..           ...      ...
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656
#
# [500 rows x 2 columns]

# %%
Ice.head()
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
Ice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
Ice.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %%
Ice.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
Y=add['Revenue']
X=add[['Temperature']]

# %%
X
# Out:
#      Temperature
# 0           24.6
# 1           26.1
# 2           27.8
# 3           20.6
# 4           11.6
# ..           ...
# 495         22.3
# 496         32.9
# 497         12.6
# 498         22.4
# 499         29.0
#
# [500 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, train_size=0.7, random_state=2529)

# %%
X_train
# Out:
#      Temperature
# 308         33.4
# 284         22.2
# 76          40.5
# 152         12.3
# 184         29.2
# ..           ...
# 228         38.2
# 399         33.6
# 316         25.2
# 50           6.4
# 352         12.8
#
# [350 rows x 1 columns]

# %%
y_train
# Out:
# 308    757
# 284    513
# 76     919
# 152    320
# 184    653
#       ...
# 228    851
# 399    751
# 316    588
# 50     191
# 352    296
# Name: Revenue, Length: 350, dtype: int64

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

from sklearn.linear_model import LinearRegression

Model=LinearRegression()

# %%
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
Model.intercept_
# Out:
# 42.444772590839705

# %%
Model.coef_
# Out:
# array([21.54587147])

# %%
y_pred=Model.predict(X_test)

# %%
y_pred
# Out:
# array([645.7291738 , 380.7149547 , 180.33835001, 247.13055157,
#        415.18834905, 283.75853308, 372.09660611, 671.58421957,
#        675.89339386, 684.51174245, 531.536055  , 613.41036659,
#        361.32367037, 303.1498174 , 158.79247854, 473.36220203,
#        611.25577945, 615.56495374, 512.14477068, 805.16862269,
#        268.67642305, 441.04339482, 436.73422053, 861.18788852,
#        531.536055  , 216.96633151, 725.44889825, 311.76816599,
#        505.68100924, 466.89844059, 684.51174245, 960.29889729,
#        550.92733933, 615.56495374, 367.78743182, 404.41541332,
#        413.03376191, 662.96587098, 876.26999855, 544.46357788,
#        811.63238414, 686.6663296 , 486.28972491, 322.54110172,
#        637.11082521, 798.70486125, 438.88880767, 790.08651266,
#        684.51174245, 497.06266065, 380.7149547 , 479.82596347,
#        479.82596347, 563.85486221, 665.12045813, 453.9709177 ,
#        688.82091675, 647.88376095, 391.48789043, 662.96587098,
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 19.138687444270737
